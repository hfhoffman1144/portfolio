# %%
import logging
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from pydantic import validate_call, EmailStr


logging.basicConfig(level=logging.INFO)
LOGGER = logging.getLogger(__name__)


@validate_call
def send_email(
    receiver_email: EmailStr,
    sender_email: EmailStr,
    password: str,
    subject: str,
    body: str,
) -> bool:

    # Create the email
    msg = MIMEMultipart()
    msg["From"] = sender_email
    msg["To"] = receiver_email
    msg["Subject"] = subject
    msg.attach(MIMEText(body, "plain"))

    # Connect to the Gmail server and send the email
    try:
        server = smtplib.SMTP("smtp.gmail.com", 587)
        server.starttls()
        server.login(sender_email, password)
        text = msg.as_string()
        server.sendmail(sender_email, receiver_email, text)

        LOGGER.info("Email sent successfully.")

        return True

    except Exception as e:

        LOGGER.info(f"Error: {e}")

        return False

    finally:

        server.quit()

# %%
receiver_emails = [
    "permits@cityofmelissa.com",
    "pzplace2@cityofmelissa.com",
    "pzplace3@cityofmelissa.com",
    "pzplace4@cityofmelissa.com",
    "pzplace5@cityofmelissa.com",
    "pzplace6@cityofmelissa.com",
    "pzplace7@cityofmelissa.com",
    "pzalternate1@cityofmelissa.com",
    "tbrewer@cityofmelissa.com"
]
sender_email = "hhoffman.inquiries@gmail.com"
password = "inop qlke qtxl work"
subject = "Opposition to new housing developments next to liberty"
body = """ 
Hello,

We are Liberty residents and are emailing to inform you of our OPPOSITION to potential new housing development
next to Liberty. This is a bad idea because:

1. Traffic is already congested through Liberty and will only get worse
2. The Harry Mckillop Elementary is already over capacity
3. Lack of amenities
4. Drainage
5. The residents are on Greenbriar would lose all of the beautiful trees that back up to their yard
6. The landowner is inexperienced in land development
7. No traffic flow through the proposed neighborhood
8. Adjacent property access is through the proposed neighborhood

It would be greatly appreciated if this development did not happen.

Thank you
"""

for receiver_email in receiver_emails:
    send_email(
        receiver_email=receiver_email,
        sender_email=sender_email,
        password=password,
        subject=subject,
        body=body
    )
# Out:
# INFO:__main__:Email sent successfully.
# INFO:__main__:Email sent successfully.
# INFO:__main__:Email sent successfully.
# INFO:__main__:Email sent successfully.
# INFO:__main__:Email sent successfully.
# INFO:__main__:Email sent successfully.
# INFO:__main__:Email sent successfully.
# INFO:__main__:Email sent successfully.
# INFO:__main__:Email sent successfully.
